# %% [markdown]
# ####  Classes and Objects
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects. This lesson covers the basics of creating classes and objects, including instance variables and methods.

# %%
# A class is a blue print for creating objects.Attributes, methods


class Car:
    pass 

audi = Car()
bmw = Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x00000233322CD760>
# <__main__.Car object at 0x00000233322CC7D0>

# %%
bmw

# %%
bmw.doors = 4

# %%
print(bmw.doors)
# Out:
# 4

# %%
print(audi.doors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(audi.doors)
#
# AttributeError: 'Car' object has no attribute 'doors'

# %%
dir(bmw)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## creating instance variables and methods 


class Dog:
    ### constructor 
    def __init__(self,name,age):
        self.name = name 
        self.age = age

# %%
dog1 = Dog("chintu bhai",12)

# %%
print(dog1)
# Out:
# <__main__.Dog object at 0x0000023332364200>

# %%
print(dog1.name)
# Out:
# chintu bhai

# %%
print(dog1.age)
# Out:
# 12

# %%
dog2 = Dog("husky",6)


print(dog2.name)
print(dog2.age)
# Out:
# husky
# 6

# %%
## define a class with instance methods


class Dog:
    ### constructor 
    def __init__(self,name,age):
        self.name = name 
        self.age = age
    def bark(self):
        print(f'{self.name} say bow bow')
    def greet(self):
        print(f'{self.name} say ala vunnav bhaya')
        
dog1=  Dog("Chintu bhai",4)

# %%
dog1.bark()
# Out:
# Chintu bhai say bow bow

# %%
dog1.greet()
# Out:
# Chintu bhai say ala vunnav bhaya

# %%
### Modeling a Bank Account

## Define a class for bank account
class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New Balance is {self.balance}")

    def get_balance(self):
        return self.balance

# %%
account = BankAccount("sai bhaai",200)

# %%
print(account.balance)
# Out:
# 200

# %%
account.deposit(1000)
# Out:
# 1000 is deposited. New balance is 1200

# %%
account.withdraw(1200)
# Out:
# 1200 is withdrawn. New Balance is 0

# %%
print(account.get_balance())
# Out:
# 0

# %% [markdown]
# #### Conclusion
# Object-Oriented Programming (OOP) allows you to model real-world scenarios using classes and objects. In this lesson, you learned how to create classes and objects, define instance variables and methods, and use them to perform various operations. Understanding these concepts is fundamental to writing effective and maintainable Python code.

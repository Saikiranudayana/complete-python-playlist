# %% [markdown]
# ##### Standard Library Overview
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array 

arr = array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math 

print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from packages.sub_packages import math

math.multiplication(7,8)
# Out:
# 56

# %%
import random 

print(random.randint(1,10))
# Out:
# 8

# %%
print(random.choice(['apple','banana','cherry']))
# Out:
# cherry

# %%
## file and directory access

import os 
print(os.getcwd())
# Out:
# c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\5-Modules

# %%
os.mkdir('test_dir')

# %%
#high level operation 
import shutil

shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization

import json 

data = {'name':'sai','age':25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "sai", "age": 25}
# <class 'str'>
# {'name': 'sai', 'age': 25}
# <class 'dict'>

# %%
#csv operaations

import csv 

with open('exmple.csv',mode='w',newline='')as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['sai',30])
    
    
with open('exmple.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['sai', '30']

# %%
#data time 
from datetime import datetime,timedelta 

now = datetime.now()
print(now)
# Out:
# 2026-06-17 15:06:43.278183

# %%
import time
print(time.time()) 
time.sleep(2)
print(time.time())
# Out:
# 1781689071.9258652
# 1781689073.9277205

# %%
time.sleep(2)
print(time.time())
# Out:
# 1781689064.3424566

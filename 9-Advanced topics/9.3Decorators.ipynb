# %% [markdown]
# #### Decorators
# Decorators are a powerful and flexible feature in Python that allows you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code. This lesson covers the basics of decorators, including how to create and use them.

# %%
### function copy
### closures
### decorators

# %%
## function copy

def welcome():
    return "Marupu chednhinavade manishi"

welcome()
# Out:
# 'Marupu chednhinavade manishi'

# %%
wel = welcome
print(wel())
del welcome

print(wel())
# Out:
# Marupu chednhinavade manishi
# Marupu chednhinavade manishi

# %%
## closures functions

def main_welcome(msg):
    
    def sub_welcome_method():
        print("welcome bahaya")
        print(msg)
        print("ela vunnav")
    return sub_welcome_method()

# %%
main_welcome("surya bhaai")
# Out:
# welcome bahaya
# surya bhaai
# ela vunnav

# %%
def main_welcome(func):
    
    def sub_welcome_method():
        print("welcome bahaya")
        func("welcome to this adda")
        print("ela vunnav")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# welcome bahaya
# welcome to this adda
# ela vunnav

# %%
def main_welcome(func,lst):
    
    def sub_welcome_method():
        print("welcome bahaya")
        print(func(lst))
        print("ela vunnav")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5])
# Out:
# welcome bahaya
# 5
# ela vunnav

# %%
## decotrators


def main_welcome(func):
    
    def sub_welcome_method():
        print("welcome bahaya")
        func()
        print("ela vunnav")
    return sub_welcome_method()

# %%
def gang_intro():
    print("edhi mana gang")
    
gang_intro()
# Out:
# edhi mana gang

# %%
main_welcome(gang_intro)
# Out:
# welcome bahaya
# edhi mana gang
# ela vunnav

# %%
@main_welcome
def gang_intro():
    print("edhi mana gang")
# Out:
# welcome bahaya
# edhi mana gang
# ela vunnav

# %%
## Decorators WWith arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("hi broo")

# %%
say_hello()
# Out:
# hi broo
# hi broo
# hi broo

# %% [markdown]
# #### Conclusion
# Decorators are a powerful tool in Python for extending and modifying the behavior of functions and methods. They provide a clean and readable way to add functionality such as logging, timing, access control, and more without changing the original code. Understanding and using decorators effectively can significantly enhance your Python programming skills.

# %% [markdown]
# #### Logging with Multiple Loggers
# You can create multiple loggers for different parts of your application.

# %%
import logging

## create a looger for module 1 

logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)


## create a looger ofr module 2 
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)


## configurations

logging.basicConfig(
    level= logging.DEBUG,
    format = '%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt = '%Y-%m-%d %H:%M:%S'
)

# %%
##lo mesage 

logger1.debug("this is debug message")
# Out:
# 2026-06-23 20:28:17-module1-DEBUG-this is debug message

# %%
logger2.warning("This is a warning message for module 2")
# Out:
# 2026-06-23 20:28:49-module2-WARNING-This is a warning message for module 2

# %% [markdown]
# #### Pandas-DataFrame And Series
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd 

data = [1,2,3,4,5]
series = pd.Series(data)
print("series \n",series)
print(type(series))
# Out:
# series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>

# %%
## create a series from dict 

data = {'a':1,'b':2,'c':3}

series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']

pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## data frames


data = {
    'Name':['Roshan babu','attitude star','kaysidhu'],
    'age':[26,28,27],
    'city':['Blr','hyd','chennai']
}

# %%
df= pd.DataFrame(data)

# %%
df
print(df)
# Out:
#             Name  age     city
# 0    Roshan babu   26      Blr
# 1  attitude star   28      hyd
# 2       kaysidhu   27  chennai

# %%
df
# Out:
#             Name  age     city
# 0    Roshan babu   26      Blr
# 1  attitude star   28      hyd
# 2       kaysidhu   27  chennai

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
sales_data = pd.read_csv('sales_data.csv')

# %%
sales_data.head(10)
# Out:
#    Transaction ID        Date Product Category                 Product Name  \
# 0           10001  2024-01-01      Electronics                iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances             Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing             Levi's 501 Jeans
# 3           10004  2024-01-04            Books            The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products      Neutrogena Skincare Set
# 5           10006  2024-01-06           Sports  Wilson Evolution Basketball
# 6           10007  2024-01-07      Electronics          MacBook Pro 16-inch
# 7           10008  2024-01-08  Home Appliances         Blueair Classic 480i
# 8           10009  2024-01-09         Clothing             Nike Air Force 1
# 9           10010  2024-01-10            Books        Dune by Frank Herbert
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
# 5           5       29.99         149.95           Asia    Credit Card
# 6           1     2499.99        2499.99  North America    Credit Card
# 7           2      599.99        1199.98         Europe         PayPal
# 8           6       89.99         539.94           Asia     Debit Card
# 9           2       25.99          51.98  North America    Credit Card

# %%
sales_data.tail(10)
# Out:
#      Transaction ID        Date Product Category  \
# 230           10231  2024-08-18         Clothing
# 231           10232  2024-08-19            Books
# 232           10233  2024-08-20  Beauty Products
# 233           10234  2024-08-21           Sports
# 234           10235  2024-08-22      Electronics
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 230                  Adidas Originals Trefoil Hoodie           4       64.99
# 231                            Dune by Frank Herbert           2        9.99
# 232                        Fresh Sugar Lip Treatment           1       24.00
# 233          Hydro Flask Standard Mouth Water Bottle           3       32.95
# 234      Bose QuietComfort 35 II Wireless Headphones           1      299.00
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 230         259.96           Asia     Debit Card
# 231          19.98  North America    Credit Card
# 232          24.00         Europe         PayPal
# 233          98.85           Asia    Credit Card
# 234         299.00  North America    Credit Card
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# 238          55.00         Europe         PayPal
# 239          59.98           Asia    Credit Card

# %%
df
# Out:
#             Name  age     city
# 0    Roshan babu   26      Blr
# 1  attitude star   28      hyd
# 2       kaysidhu   27  chennai

# %%
df['Name']
# Out:
# 0      Roshan babu
# 1    attitude star
# 2         kaysidhu
# Name: Name, dtype: str

# %%
df.loc[0]
# Out:
# Name    Roshan babu
# age              26
# city            Blr
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name    Roshan babu
# age              26
# city            Blr
# Name: 0, dtype: object

# %%
df
# Out:
#             Name  age     city
# 0    Roshan babu   26      Blr
# 1  attitude star   28      hyd
# 2       kaysidhu   27  chennai

# %%
print(df.at[1,'age'])
# Out:
# 28

# %%
print(df.at[0,'Name'])
# Out:
# Roshan babu

# %%
df
# Out:
#             Name  age     city
# 0    Roshan babu   26      Blr
# 1  attitude star   28      hyd
# 2       kaysidhu   27  chennai

# %%
df['Fanbse']=[50000,60000,76000]

# %%
df
# Out:
#             Name  age     city  Fanbse
# 0    Roshan babu   26      Blr   50000
# 1  attitude star   28      hyd   60000
# 2       kaysidhu   27  chennai   76000

# %%
##remove a column

df.drop('Fanbse',axis= 1,inplace=True)

# %%
df
# Out:
#             Name  age     city
# 0    Roshan babu   26      Blr
# 1  attitude star   28      hyd
# 2       kaysidhu   27  chennai

# %%
sales_data
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# 3                                  The Da Vinci Code           4       15.99
# 4                            Neutrogena Skincare Set           1       89.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 0          1999.98  North America    Credit Card
# 1           499.99         Europe         PayPal
# 2           209.97           Asia     Debit Card
# 3            63.96  North America    Credit Card
# 4            89.99         Europe         PayPal
# ..             ...            ...            ...
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# 238          55.00         Europe         PayPal
# 239          59.98           Asia    Credit Card
#
# [240 rows x 9 columns]

# %%
# Display the data types of each column
print("Data types:\n", sales_data.dtypes)

# Describe the DataFrame
print("Statistical summary:\n", sales_data.describe())
# Out:
# Data types:
#  Transaction ID        int64
# Date                    str
# Product Category        str
# Product Name            str
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region                  str
# Payment Method          str
# dtype: object
# Statistical summary:
#         Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
sales_data.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

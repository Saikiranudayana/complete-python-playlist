# %% [markdown]
# #### File Operation- Read And Write Files
#
# File handling is a crucial part of any programming language. Python provides built-in functions and methods to read from and write to files, both text and binary. This lesson will cover the basics of file handling, including reading and writing text files and binary files.

# %%
## read a whole file 

with open('example.txt','r')as file:
    content= file.read()
    print(content)
# Out:
# Hello nana kanna
# rey rey bondam nene

# %%
with open('example.txt','r')as file:
    for line in file:
        print(line.strip())
# Out:
# Hello nana kanna
# rey rey bondam nene

# %%
with open('example.txt','w')as file:
    file.write('rey chala papam ra\n')
    file.write('oka smile isthadhu')

# %%
with open('example.txt','r')as file:
    for line in file:
        print(line.strip())
# Out:
# rey chala papam ra
# oka smile isthadhu

# %%
with open('example.txt','a')as file:
    file.write("\n adding  a new line\n")

# %%
with open('example.txt','r')as file:
    for line in file:
        print(line.strip())
# Out:
# rey chala papam ra
# oka smile isthadhuadding  a new lineadding  a new line
#
# adding  a new line

# %%
## writing a list of lines to  file 

lines = ['First line\n','second line\n','third line\n']

with open ('example.txt','a') as file:
    file.writelines(lines)

# %%
with open('example.txt','r')as file:
    for line in file:
        print(line.strip())
# Out:
# rey chala papam ra
# oka smile isthadhuadding  a new lineadding  a new line
#
# adding  a new line
# First line
# second line
# third line

# %%
### Binary Files

# Writing to a binary file
data = b'\x00\x01\x02\x03\x04'
with open('example.bin', 'wb') as file:
    file.write(data)

# %%
# Reading a binary file
with open('example.bin', 'rb') as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
# reading a conent form socure text fiel and write to a destination text file

with open('example.txt','r')as source_file:
    content = source_file.read()
    
with open('destination.txt','w')as destination_file:
    destination_file.write(content)

# %%
### Writing and then reading a file

with open('example.txt','w+') as file:
    file.write("Hello world\n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning
    file.seek(0)

    ## Read the content of the file
    content=file.read()
    print(content)
# Out:
# Hello world
# This is a new line

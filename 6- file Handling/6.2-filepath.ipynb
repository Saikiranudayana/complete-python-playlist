# %% [markdown]
# #### Working With File Paths
# When working with files in Python, handling file paths correctly is crucial to ensure your code works across different operating systems and environments. Python provides several modules and functions for working with file paths effectively.

# %%
## using the os modules

import os 
cwd = os.getcwd()
print(f"current working directory is {cwd}")
# Out:
# current working directory is c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\6- file Handling

# %%
## create ew working directory
new_direcotry = "Package"
os.mkdir(new_direcotry)

# %%
print(f"creted directory is '{new_direcotry}'")
# Out:
# creted  directory is 'Package'

# %%
## lisiting all files and direcotries

items = os.listdir('.')
print(items)
# Out:
# ['6.1-file operations.ipynb', '6.2-filepath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'Package']

# %%
## joining paths 

dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\6- file Handling\folder\file.txt

# %%
path1 = 'example.txt'

if os.path.exists(path1):
    print(f"the path '{path}' exists")
else:
    print(f"the path '{path1}' does not exists")
# Out:
# the path 'exmple1.txt' exists

# %%
import os

path = ''
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The path 'Package' is a directory.

# %%
a = 'example.txt'
absoulte_path = os.path.abspath(a)

# %%
print(absoulte_path)
# Out:
# c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\6- file Handling\example.txt

# %% [markdown]
# #### Dictionaries
# Video Outline:
# 1. Introduction to Dictionaries
# 2. Creating Dictionaries
# 3. Accessing Dictionary Elements
# 4. Modifying Dictionary Elements
# 5. Dictionary Methods
# 6. Iterating Over Dictionaries
# 7. Nested Dictionaries
# 8. Dictionary Comprehensions
# 9. Practical Examples and Common Errors

# %% [markdown]
# ##### Introduction to Dictionaries
#
# Dictionaries are unordered collections of items. They store data in key-value pairs.
# Keys must be unique and immutable (e.g., strings, numbers, or tuples), while values can be of any type.

# %%
## creating dict 
empty_dict = {}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict = dict() 
empty_dict
# Out:
# {}

# %%
student = {"name":"sai","age":32,"grade":9}

# %%
print(student)
print(type(student))
# Out:
# {'name': 'sai', 'age': 32, 'grade': 9}
# <class 'dict'>

# %%
##single key is always used 
student = {"name":"sai","age":32,"grade":9 ,"name":"roshan babu"}

# %%
print(student)
# Out:
# {'name': 'roshan babu', 'age': 32, 'grade': 9}

# %%
## accesing in dict elemts

student = {"name":"roshan babu","age":32,"grade":9}

# %%
student['grade']
# Out:
# 9

# %%
student['age']
# Out:
# 32

# %%
## acccesing using .get() method 

print(student.get('grade'))
# Out:
# 9

# %%
print(student.get('last_name',"NOt available"))
# Out:
# NOt available

# %%
student
# Out:
# {'name': 'roshan babu', 'age': 33, 'grade': 9, 'aage': 33}

# %%
student['age']=33

# %%
student
# Out:
# {'name': 'roshan babu', 'age': 33, 'grade': 9, 'aage': 33}

# %%
student["movie"]="premakulam"

# %%
student
# Out:
# {'name': 'roshan babu',
#  'age': 33,
#  'grade': 9,
#  'aage': 33,
#  'movie': 'premakulam'}

# %%
del student['aage']

# %%
student
# Out:
# {'name': 'roshan babu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}

# %%
## dict methods

keys = student.keys()
print(keys)
# Out:
# dict_keys(['name', 'age', 'grade', 'movie'])

# %%
values= student.values()
print(values)
# Out:
# dict_values(['roshan babu', 33, 9, 'premakulam'])

# %%
items = student.items()
print(items)
# Out:
# dict_items([('name', 'roshan babu'), ('age', 33), ('grade', 9), ('movie', 'premakulam')])

# %%
student
# Out:
# {'name': 'roshan babu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}

# %%
student_copy = student

# %%
print(student)
print(student_copy)
# Out:
# {'name': 'roshan babu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}
# {'name': 'roshan babu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}

# %%
student['name']= "kaysidhu"

# %%
print(student)
print(student_copy)
# Out:
# {'name': 'kaysidhu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}
# {'name': 'kaysidhu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}

# %%
student
# Out:
# {'name': 'kaysidhu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}

# %%
student_copy1 = student.copy()

# %%
print(student)
print(student_copy1)
# Out:
# {'name': 'kaysidhu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}
# {'name': 'kaysidhu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}

# %%
student['name']= "rakesh master"

# %%
print(student)
print(student_copy1)
# Out:
# {'name': 'rakesh master', 'age': 33, 'grade': 9, 'movie': 'premakulam'}
# {'name': 'kaysidhu', 'age': 33, 'grade': 9, 'movie': 'premakulam'}

# %%
##itreations

for keys in student.keys():
    print(keys)
# Out:
# name
# age
# grade
# movie

# %%
for value in student.values():
    print(value)
# Out:
# rakesh master
# 33
# 9
# premakulam

# %%
for key,value in student_copy1.items():
    print(f"{key}:{value}")
# Out:
# name:kaysidhu
# age:33
# grade:9
# movie:premakulam

# %%
## nested dictioneries 

students = {
    "student1":{"name":"peddi","age":34},
    "student2":{"name":"Buchhi babu","age":33}
}

# %%
print(students)
# Out:
# {'student1': {'name': 'peddi', 'age': 34}, 'student2': {'name': 'Buchhi babu', 'age': 33}}

# %%
print(students["student1"]["name"])
print(students["student2"]["age"])
# Out:
# peddi
# 33

# %%
# Out:
# dict_items([('student1', {'name': 'peddi', 'age': 34}), ('student2', {'name': 'Buchhi babu', 'age': 33})])

# %%
## itreations 

for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'peddi', 'age': 34}
# name:peddi
# age:34
# student2:{'name': 'Buchhi babu', 'age': 33}
# name:Buchhi babu
# age:33

# %%
## dict comphers 

squares = { x:x**2 for x in range(11)}

# %%
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
## Condition dictionary comprehension
evens={x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical Examples

## USe a dictionary to count he frequency of elements in list

numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %% [markdown]
# #### Tuples
# Video Outline:
# 1. Introduction to Tuples
# 2. Creating Tuples
# 3. Accessing Tuple Elements
# 4. Tuple Operations
# 5. Immutable Nature of Tuples
# 6. Tuple Methods
# 7. Packing and Unpacking Tuples
# 8. Nested Tuples
# 9. Practical Examples and Common Errors

# %% [markdown]
# ##### Introduction to Tuples
# Explanation:
#
# Tuples are ordered collections of items that are immutable.
# They are similar to lists, but their immutability makes them different.

# %%
lst = []

empty_tuple= ()

# %%
empty_tuple
print(type(empty_tuple))
# Out:
# <class 'tuple'>

# %%
lst = list()
print(type(lst))

tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
[1,2,3,4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nums = tuple([1,2,3,4,5,6])

# %%
nums
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(type(tuple([1,2,3,4,5,6])))
# Out:
# <class 'tuple'>

# %%
mixed_tuple = ("prabhas1,",6.2,True)

print(mixed_tuple)
# Out:
# (1, 'prabhas', 6.2, True)

# %%
#acessing tuple elements

nums
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
nums[2]
# Out:
# 3

# %%
nums[-1]
# Out:
# 6

# %%
nums
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
nums[0:4]
# Out:
# (1, 2, 3, 4)

# %%
nums[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
#tuple operations

nums
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
mixed_tuple
# Out:
# (1, 'prabhas', 6.2, True)

# %%
concated_tuple = nums+mixed_tuple

# %%
concated_tuple
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'prabhas', 6.2, True)

# %%
nums*2
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
mixed_tuple*3
# Out:
# (1, 'prabhas', 6.2, True, 1, 'prabhas', 6.2, True, 1, 'prabhas', 6.2, True)

# %%
lst = [1,2,3,4,5]
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
lst[1]="sai"

# %%
print(lst)
# Out:
# [1, 'sai', 3, 4, 5]

# %%
nums
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
nums[1]="sai"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 nums[1]="sai"
#
# TypeError: 'tuple' object does not support item assignment

# %%
nums
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#tuple methods 
print(nums.count(1))
# Out:
# 1

# %%
print(nums.index(3))
# Out:
# 2

# %%
#packing tuples
packed_tuple = 1,"hello",3.14 
print(packed_tuple)
# Out:
# (1, 'hello', 3.14)

# %%
a,b,c= packed_tuple

print(a)
print(b)
print(c)
# Out:
# 1
# hello
# 3.14

# %%
nums = (1,2,3,4,5,6)

first,*middle,last = nums

# %%
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
#nested list 
lst = [[1,2,3,4],[6,7,8,9],[1,"heelo",3.14,'c']]

# %%
lst[0][1:3]
# Out:
# [2, 3]

# %%
lst[1][2:4]
# Out:
# [8, 9]

# %%
nested_tuples = ((1,2,3),("a","b","C"),(True,False))

# %%
nested_tuples[0]
# Out:
# (1, 2, 3)

# %%
nested_tuples[1][2]
# Out:
# 'C'

# %%
for sub_tuple in nested_tuples:
    for item in sub_tuple:
        print(item,end=" ")
    print()
# Out:
# 1 2 3
# a b C
# True False

# %% [markdown]
# #### Conclusion
# Tuples are versatile and useful in many real-world scenarios where an immutable and ordered collection of items is required. They are commonly used in data structures, function arguments and return values, and as dictionary keys. Understanding how to leverage tuples effectively can improve the efficiency and readability of your Python code.
